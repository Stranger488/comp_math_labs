# %%
def l_i(i, x, x_nodes):
    li = 1
    
    for j in range(len(x_nodes)):
        if j != (i - 1):
            li *= (x - x_nodes[j]) / (x_nodes[i - 1] - x_nodes[j])
    return li

# %%
print(l_i(1,0.5, [1,2,3,4,5]))
# Out:
# 2.4609375

# %%
def L(x, x_nodes, y_nodes):
    Lx = 0
    
    for i in range(len(x_nodes)):
        Lx += y_nodes[i] * l_i(i + 1, x, x_nodes)
    return Lx

# %%
print(L(0.5, [1,2,3], [5,6,7]))
# Out:
# 4.5

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(x):
    return np.exp(-x**2)

def get_cmap(n, name='winter'):
    '''Returns a function that maps each index in 0, 1, ..., n-1 to a distinct 
    RGB color; the keyword argument name must be a standard mpl colormap name.'''
    return plt.cm.get_cmap(name, n)


def cheb_nodes(num):
    x_cheb = []
    for k in range(num):
        x_cheb.append(math.cos((2 * (k + 1) - 1) * math.pi / (2 * num)))
    return x_cheb

# %%
x = np.linspace(-5., 5., 200, endpoint=True)
fx = f(x)
N = np.arange(4, 21)

cmap = get_cmap(len(N))

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 8), dpi=100)
axes.plot(x, fx, color="red", linewidth=2.0)

for n in N:
    x_nodes_evenly_distributed = np.linspace(-5., 5., n)
    axes.plot(x, L(x, x_nodes_evenly_distributed, f(x_nodes_evenly_distributed)), color=cmap(n - 4), linestyle='--', label=str(n)) 

axes.legend()
axes.legend(loc='upper left')
axes.grid()

plt.show()

# %%
norm_evenly = []
norm_cheb = []
norm_kus_lin = []

for n in N:
    max_diff = -1
    x_nodes_evenly_distributed = np.linspace(-5., 5., n)
    x_nodes_cheb = cheb_nodes(n)
    
    y_L = []
    for i in range(len(x)):
        y_L.append(L(x[i], x_nodes_evenly_distributed, f(x_nodes_evenly_distributed)))
        
    
    for nod in range(len(x)):
        y1_L.append(L(x[nod], x_i, y_i))
        y2_L.append(L(x[nod], x_ch, y_ch))

    dif_i = [] # норма по интерполяционным узлам
    dif_ch = [] # норма по Чебышевским узлам
    
    for i in range(len(x)):
        dif_i.append(np.abs(y[i] - y1_L[i]))
        dif_ch.append(np.abs(y[i] - y2_L[i]))

    norm_inter.append(max(dif_i))
    norm_cheb.append(max(dif_ch))
    
    for j in range(len(y_L)):
        temp = np.abs(f(x[j]) - y_L[j])
        if (temp > max_diff):
            max_diff = temp
    norm.append(max_diff)
    
#     ksi = np.random.uniform(-5., 5.)
#     temp = derivative(f(x), ksi, n=n)
    

    
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8, 6), dpi=100)
axes.semilogy(N, norm, '--o', color="blue", linewidth=1.0, linestyle='--')
axes.grid()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-124-6e4bcc070e81> in <module>
# ----> 1 from scipy.misc import derivative
#       2
#       3
#       4 norm = []
#       5 for n in N:
#
# ModuleNotFoundError: No module named 'scipy'
